# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("2e/drop_0.1/loss_250.log")

# %%
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2e/drop0.4/loss_300.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2e/drop0.4/loss_300.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2f/loss_800.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2g/loss_550.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2h/loss_750.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2i/loss_950.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j/loss_850.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-drop03/loss_650.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-time/loss.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2k/loss.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-l2/loss.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-l2/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-lay3/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-k5/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-ramdomMask/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-adamW/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-adamW-0.3/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-adamW-0.2/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-adamW-0.1/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2j-adamW/loss_timestrech.log")
df2 = pd.read_csv("2j-adamW-0.1/loss_timestrech.log")
df3 = pd.read_csv("2j-adamW-0.3/loss_timestrech.log")
df4 = pd.read_csv("2j-adamW-0.2/loss_timestrech.log")



plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
#plt.plot(df['train_loss'], label="1")
plt.plot(df['test_loss'], label="0.01")

#plt.plot(df2['train_loss'], label="2")
plt.plot(df2['test_loss'], label="0.1")

#plt.plot(df3['train_loss'], label="3")
plt.plot(df3['test_loss'], label="0.3")

plt.plot(df4['test_loss'], label="0.2")


plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)


plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="0.01")
plt.plot(df['test_F1_score'], label="0.01")

plt.plot(df2['train_F1_score'], label="0.1")
plt.plot(df2['test_F1_score'], label="0.1")

#plt.plot(df3['train_F1_score'], label="3")
#plt.plot(df3['test_F1_score'], label="0.3")

plt.plot(df4['train_F1_score'], label="0.2")
plt.plot(df4['test_F1_score'], label="0.2")


plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("2k/loss_timestrech.log")
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.ylim(0.005, 0.03)
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 0.5), loc='upper right', borderaxespad=0, fontsize=10)

# %%
df = pd.read_csv("lr/loss.log")

# %%
df.head()
# Out:
#    Unnamed: 0  train_loss  test_loss  train_F1_score  test_F1_score
# 0          10    0.677657   0.676697        0.004790       0.003965
# 1          10    0.513761   0.502666        0.002512       0.003965
# 2          10    0.025493   0.025526        0.007418       0.004897
# 3          10    0.025104   0.024992        0.006016       0.006063
# 4          10    0.025111   0.025042        0.004322       0.005290

# %%
plt.figure(figsize=(14, 3))

plt.subplot(1,2,1)
plt.plot(df['train_loss'], label="train")
plt.plot(df['test_loss'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

plt.subplot(1,2,2)
plt.plot(df['train_F1_score'], label="train")
plt.plot(df['test_F1_score'], label="test")
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=10)

# %%
import numpy as np
import scipy as sp
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

# %%
np.random.seed(1)
